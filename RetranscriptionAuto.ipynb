# %% [markdown]
# <a href="https://colab.research.google.com/github/Louis28240/Louis-test-retranscription/blob/main/RetranscriptionAuto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AVANT DE LANCER LE CODE ! FAITES UNE COPIE DE DOC SUR VOTRE COMPTE GOOGLE DRIVE ! UTILISEZ LA VERSION SUR VOTRE GOOGLE DRIVE PLUTÔT QUE CELLE-CI**
#
# **fichier --> enregister une copie dans google drive**
#
#
# --------------------------------------------------------------------------------

# %% [markdown]
# **Il faut lancer la ligne de code du dessous en 1er**
#
#
# **⬇**

# %%
from torch import cuda
cuda.get_device_name(0)
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg

# %% [markdown]
# **Il faut choisir la puissance du modèle. Avec le script, vous pouvez utiliser la plus puissante (large-V3) car ce code n'utilise pas les perfomances de votre pc**
#
# **ATTENTION !!! sous la ligne de code, cela va vous demander de déposer le fichier (le truc est pas hyper visible...). Ça ressemble à cela :**
#
# ![Capture d’écran 2024-11-29 182639.png](data:image/png;base64,...)
#
#
# **⬇**

# %%
from google.colab import files
uploaded = files.upload()


filename = list(uploaded.keys())[0]

model = "medium"  # @param ["base", "medium", "turbo", "large-v3"]
langage = "French"  # @param ["French", "English"]

# !whisper --model {model} --language {langage} --output_format txt "{filename}"

# %% [markdown]
# **À la fin, votre fichier se trouve dans le dossier ici**
#
# ![fichier.png](data:image/png;base64,...)
#
# **Il y a dans la liste, logiquement le fichier en .txt**

# %% [markdown]
# --------------------------------------------------------------------------------
#
# **Si vous voulez une restitution 100% fidèle, vous pouvez suivre cette manipulation :**
#
#
# contrôle + C et contrôle + V l’entretien dans word.
# Il faut ensuite retirer tous les sauts de ligne. Pour cela, contrôle + H, puis il faut aller dans remplacer, et tu tapes cela :
#
# ![ctrl h retranscription.png](data:image/png;base64,...)
#
#
# Normalement, vous avez un gros bloc avec 0 saut de ligne.
#
# Il restera donc à relire le document et ajouter les sauts de ligne quand il y a un changement de personne qui parle.

# %% [markdown]
# **Note :**
#
# Le projet est d'ajouter un script qui permet directement de déduire qui parle et qui saute les lignes automatiquement. C'est possible mais assez complexe. Je travaille dessus.
#
#
# Comme vous avez pu le voir, on peut retranscrire un audio français en texte anglais. Mais je crois que c'est un peu cassé car au bout d'un moment, cela repasse en français.
#
#
# **Si vous avez des problèmes, vous pouvez me contacter par mail :**
# louis28.thomas.lt@gmail.com
# ou
# louis.thomas-3@etu.univ-tours.fr
#
# Avec l'aide de THOMAS Guylain (pas mon frère même si même nom de famille).

# %% [markdown]
# *c'est mon doc donc je peux dire ce que je veux !*
#
# *Allez l'OM*
#
# *Bleach >>> One piece >>> Naruto*
